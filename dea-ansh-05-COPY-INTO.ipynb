# %%
# %sql
SELECT * from parquet.`/Volumes/ansh_catalog/bronze/autovolume/copyinto/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
DROP TABLE ansh_catalog.bronze.copyintotable

# %%
# %sql
CREATE TABLE IF NOT EXISTS ansh_catalog.bronze.copyintotable
(
  order_id INT,
  customer_id INT,
  order_date DATE,
  order_amount DOUBLE,
  order_status STRING
)

# %%
# %sql
COPY INTO ansh_catalog.bronze.copyintotable
FROM "/Volumes/ansh_catalog/bronze/autovolume/copyinto/"
FILEFORMAT = parquet
FORMAT_OPTIONS ('mergeSchema'= 'True')
COPY_OPTIONS ('mergeSchema'= 'True')

# %%
# %sql
SELECT * FROM ansh_catalog.bronze.copyintotable
