# %%
### DB Utilities

# %%
dbutils.help()

# %%
dbutils.help("fs")

# %%
dbutils.fs.ls("/Volumes/gizmobox/landing/operational_data")

# %%
dbutils.fs.mkdirs("/Volumes/gizmobox/landing/operational_data/dbutilstest")

# %%
dbutils.fs.cp("/Volumes/gizmobox/landing/operational_data/addresses/", "/Volumes/gizmobox/landing/operational_data/dbutilstest/", True)

# %%
dbutils.fs.rm("/Volumes/gizmobox/landing/operational_data/dbutilstest", True)

# %%
all_items = dbutils.fs.ls("/Volumes/gizmobox/landing/operational_data/addresses/")
all_items

# %%
file_names = [i.name for i in all_items]
file_names

# %% [markdown]
# ### Create a parameter

# %%
dbutils.widgets.text("par1", "")

# %%
par_value = dbutils.widgets.get("par1")
par_value
