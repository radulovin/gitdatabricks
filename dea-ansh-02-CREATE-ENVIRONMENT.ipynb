# %% [markdown]
# ### Create the environment

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ansh_catalog;
USE CATALOG ansh_catalog;

# %%
# %sql
USE CATALOG ansh_catalog;
select current_catalog();
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE VOLUME IF NOT EXISTS bronze.bronze_volume;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
dbutils.fs.mkdirs("/Volumes/ansh_catalog/bronze/bronze_volume/customers")
dbutils.fs.mkdirs("/Volumes/ansh_catalog/bronze/bronze_volume/products")
dbutils.fs.mkdirs("/Volumes/ansh_catalog/bronze/bronze_volume/sales")
dbutils.fs.mkdirs("/Volumes/ansh_catalog/bronze/bronze_volume/stores")
dbutils.fs.ls("/Volumes/ansh_catalog/bronze/bronze_volume")
