# %% [markdown]
# ## Copy into table

# %%
# Copy into
spark.sql("""
COPY INTO firstcactalog.firstschema.online_retail_sql
FROM '/Volumes/firstcatalog/firstschema/firstvolume'
FILEFORMAT = CSV
FORMAT_OPTIONS (
  'header' = 'true',
  'inferShema' = 'true'
)
""").display()
